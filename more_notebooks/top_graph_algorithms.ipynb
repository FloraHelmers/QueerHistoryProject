# %%
# for some basic operations
import numpy as np 
import pandas as pd 

# for basic visualizations
import matplotlib.pyplot as plt
import seaborn as sns

# for network visualizations
import networkx as nx

# %%
edgelist = [['Mannheim', 'Frankfurt', 85], ['Mannheim', 'Karlsruhe', 80], ['Erfurt', 'Wurzburg', 186], ['Munchen', 'Numberg', 167], ['Munchen', 'Augsburg', 84], ['Munchen', 'Kassel', 502], ['Numberg', 'Stuttgart', 183], ['Numberg', 'Wurzburg', 103], ['Numberg', 'Munchen', 167], ['Stuttgart', 'Numberg', 183], ['Augsburg', 'Munchen', 84], ['Augsburg', 'Karlsruhe', 250], ['Kassel', 'Munchen', 502], ['Kassel', 'Frankfurt', 173], ['Frankfurt', 'Mannheim', 85], ['Frankfurt', 'Wurzburg', 217], ['Frankfurt', 'Kassel', 173], ['Wurzburg', 'Numberg', 103], ['Wurzburg', 'Erfurt', 186], ['Wurzburg', 'Frankfurt', 217], ['Karlsruhe', 'Mannheim', 80], ['Karlsruhe', 'Augsburg', 250],["Mumbai", "Delhi",400],["Delhi", "Kolkata",500],["Kolkata", "Bangalore",600],["TX", "NY",1200],["ALB", "NY",800]]

# %%
# Undirected Graphs
'''
['bipartite_layout',
 'circular_layout',
 'kamada_kawai_layout',
 'random_layout',
 'rescale_layout',
 'shell_layout',
 'spring_layout',
 'spectral_layout',
 'fruchterman_reingold_layout']
 '''
g = nx.Graph()
for edge in edgelist:
    g.add_edge(edge[0],edge[1], weight = edge[2])

import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (11, 11)
#plt.style.use('fivethirtyeight')

pos = nx.spring_layout(g)

# drawing nodes
nx.draw_networkx(g,pos)
#plt.title('Undirected Graphs', fontsize = 20)
plt.axis('off')
plt.show()

# %% [markdown]
# # 1. Connected Component

# %%
for i, x in enumerate(nx.connected_components(g)):
    print("cc"+str(i)+":",x)
# Out:
# cc0: {'Stuttgart', 'Kassel', 'Mannheim', 'Wurzburg', 'Munchen', 'Augsburg', 'Frankfurt', 'Karlsruhe', 'Numberg', 'Erfurt'}
# cc1: {'Bangalore', 'Delhi', 'Mumbai', 'Kolkata'}
# cc2: {'NY', 'TX', 'ALB'}

# %% [markdown]
# # 2. Shortest paths

# %%
print(nx.shortest_path(g, 'Stuttgart','Frankfurt',weight='weight'))
print(nx.shortest_path_length(g, 'Stuttgart','Frankfurt',weight='weight'))
# Out:
# ['Stuttgart', 'Numberg', 'Wurzburg', 'Frankfurt']
# 503

# %%
for x in nx.all_pairs_dijkstra_path(g,weight='weight'):
    print(x)
# Out:
# ('Mannheim', {'Mannheim': ['Mannheim'], 'Frankfurt': ['Mannheim', 'Frankfurt'], 'Karlsruhe': ['Mannheim', 'Karlsruhe'], 'Augsburg': ['Mannheim', 'Karlsruhe', 'Augsburg'], 'Kassel': ['Mannheim', 'Frankfurt', 'Kassel'], 'Wurzburg': ['Mannheim', 'Frankfurt', 'Wurzburg'], 'Munchen': ['Mannheim', 'Karlsruhe', 'Augsburg', 'Munchen'], 'Erfurt': ['Mannheim', 'Frankfurt', 'Wurzburg', 'Erfurt'], 'Numberg': ['Mannheim', 'Frankfurt', 'Wurzburg', 'Numberg'], 'Stuttgart': ['Mannheim', 'Frankfurt', 'Wurzburg', 'Numberg', 'Stuttgart']})
# ('Frankfurt', {'Frankfurt': ['Frankfurt'], 'Mannheim': ['Frankfurt', 'Mannheim'], 'Kassel': ['Frankfurt', 'Kassel'], 'Wurzburg': ['Frankfurt', 'Wurzburg'], 'Karlsruhe': ['Frankfurt', 'Mannheim', 'Karlsruhe'], 'Augsburg': ['Frankfurt', 'Mannheim', 'Karlsruhe', 'Augsburg'], 'Munchen': ['Frankfurt', 'Wurzburg', 'Numberg', 'Munchen'], 'Erfurt': ['Frankfurt', 'Wurzburg', 'Erfurt'], 'Numberg': ['Frankfurt', 'Wurzburg', 'Numberg'], 'Stuttgart': ['Frankfurt', 'Wurzburg', 'Numberg', 'Stuttgart']})
# ('Karlsruhe', {'Karlsruhe': ['Karlsruhe'], 'Mannheim': ['Karlsruhe', 'Mannheim'], 'Augsburg': ['Karlsruhe', 'Augsburg'], 'Frankfurt': ['Karlsruhe', 'Mannheim', 'Frankfurt'], 'Kassel': ['Karlsruhe', 'Mannheim', 'Frankfurt', 'Kassel'], 'Wurzburg': ['Karlsruhe', 'Mannheim', 'Frankfurt', 'Wurzburg'], 'Munchen': ['Karlsruhe', 'Augsburg', 'Munchen'], 'Numberg': ['Karlsruhe', 'Mannheim', 'Frankfurt', 'Wurzburg', 'Numberg'], 'Erfurt': ['Karlsruhe', 'Mannheim', 'Frankfurt', 'Wurzburg', 'Erfurt'], 'Stuttgart': ['Karlsruhe', 'Mannheim', 'Frankfurt', 'Wurzburg', 'Numberg', 'Stuttgart']})
# ('Erfurt', {'Erfurt': ['Erfurt'], 'Wurzburg': ['Erfurt', 'Wurzburg'], 'Numberg': ['Erfurt', 'Wurzburg', 'Numberg'], 'Frankfurt': ['Erfurt', 'Wurzburg', 'Frankfurt'], 'Munchen': ['Erfurt', 'Wurzburg', 'Numberg', 'Munchen'], 'Stuttgart': ['Erfurt', 'Wurzburg', 'Numberg', 'Stuttgart'], 'Mannheim': ['Erfurt', 'Wurzburg', 'Frankfurt', 'Mannheim'], 'Kassel': ['Erfurt', 'Wurzburg', 'Frankfurt', 'Kassel'], 'Augsburg': ['Erfurt', 'Wurzburg', 'Numberg', 'Munchen', 'Augsburg'], 'Karlsruhe': ['Erfurt', 'Wurzburg', 'Frankfurt', 'Mannheim', 'Karlsruhe']})
# ('Wurzburg', {'Wurzburg': ['Wurzburg'], 'Erfurt': ['Wurzburg', 'Erfurt'], 'Numberg': ['Wurzburg', 'Numberg'], 'Frankfurt': ['Wurzburg', 'Frankfurt'], 'Munchen': ['Wurzburg', 'Numberg', 'Munchen'], 'Stuttgart': ['Wurzburg', 'Numberg', 'Stuttgart'], 'Mannheim': ['Wurzburg', 'Frankfurt', 'Mannheim'], 'Kassel': ['Wurzburg', 'Frankfurt', 'Kassel'], 'Augsburg': ['Wurzburg', 'Numberg', 'Munchen', 'Augsburg'], 'Karlsruhe': ['Wurzburg', 'Frankfurt', 'Mannheim', 'Karlsruhe']})
# ('Munchen', {'Munchen': ['Munchen'], 'Numberg': ['Munchen', 'Numberg'], 'Augsburg': ['Munchen', 'Augsburg'], 'Kassel': ['Munchen', 'Kassel'], 'Karlsruhe': ['Munchen', 'Augsburg', 'Karlsruhe'], 'Stuttgart': ['Munchen', 'Numberg', 'Stuttgart'], 'Wurzburg': ['Munchen', 'Numberg', 'Wurzburg'], 'Erfurt': ['Munchen', 'Numberg', 'Wurzburg', 'Erfurt'], 'Frankfurt': ['Munchen', 'Numberg', 'Wurzburg', 'Frankfurt'], 'Mannheim': ['Munchen', 'Augsburg', 'Karlsruhe', 'Mannheim']})
# ('Numberg', {'Numberg': ['Numberg'], 'Munchen': ['Numberg', 'Munchen'], 'Stuttgart': ['Numberg', 'Stuttgart'], 'Wurzburg': ['Numberg', 'Wurzburg'], 'Erfurt': ['Numberg', 'Wurzburg', 'Erfurt'], 'Frankfurt': ['Numberg', 'Wurzburg', 'Frankfurt'], 'Augsburg': ['Numberg', 'Munchen', 'Augsburg'], 'Kassel': ['Numberg', 'Wurzburg', 'Frankfurt', 'Kassel'], 'Karlsruhe': ['Numberg', 'Wurzburg', 'Frankfurt', 'Mannheim', 'Karlsruhe'], 'Mannheim': ['Numberg', 'Wurzburg', 'Frankfurt', 'Mannheim']})
# ('Augsburg', {'Augsburg': ['Augsburg'], 'Munchen': ['Augsburg', 'Munchen'], 'Karlsruhe': ['Augsburg', 'Karlsruhe'], 'Numberg': ['Augsburg', 'Munchen', 'Numberg'], 'Kassel': ['Augsburg', 'Munchen', 'Kassel'], 'Mannheim': ['Augsburg', 'Karlsruhe', 'Mannheim'], 'Stuttgart': ['Augsburg', 'Munchen', 'Numberg', 'Stuttgart'], 'Wurzburg': ['Augsburg', 'Munchen', 'Numberg', 'Wurzburg'], 'Frankfurt': ['Augsburg', 'Karlsruhe', 'Mannheim', 'Frankfurt'], 'Erfurt': ['Augsburg', 'Munchen', 'Numberg', 'Wurzburg', 'Erfurt']})
# ('Kassel', {'Kassel': ['Kassel'], 'Munchen': ['Kassel', 'Munchen'], 'Frankfurt': ['Kassel', 'Frankfurt'], 'Mannheim': ['Kassel', 'Frankfurt', 'Mannheim'], 'Wurzburg': ['Kassel', 'Frankfurt', 'Wurzburg'], 'Karlsruhe': ['Kassel', 'Frankfurt', 'Mannheim', 'Karlsruhe'], 'Augsburg': ['Kassel', 'Munchen', 'Augsburg'], 'Erfurt': ['Kassel', 'Frankfurt', 'Wurzburg', 'Erfurt'], 'Numberg': ['Kassel', 'Frankfurt', 'Wurzburg', 'Numberg'], 'Stuttgart': ['Kassel', 'Frankfurt', 'Wurzburg', 'Numberg', 'Stuttgart']})
# ('Stuttgart', {'Stuttgart': ['Stuttgart'], 'Numberg': ['Stuttgart', 'Numberg'], 'Munchen': ['Stuttgart', 'Numberg', 'Munchen'], 'Wurzburg': ['Stuttgart', 'Numberg', 'Wurzburg'], 'Erfurt': ['Stuttgart', 'Numberg', 'Wurzburg', 'Erfurt'], 'Frankfurt': ['Stuttgart', 'Numberg', 'Wurzburg', 'Frankfurt'], 'Augsburg': ['Stuttgart', 'Numberg', 'Munchen', 'Augsburg'], 'Kassel': ['Stuttgart', 'Numberg', 'Wurzburg', 'Frankfurt', 'Kassel'], 'Karlsruhe': ['Stuttgart', 'Numberg', 'Wurzburg', 'Frankfurt', 'Mannheim', 'Karlsruhe'], 'Mannheim': ['Stuttgart', 'Numberg', 'Wurzburg', 'Frankfurt', 'Mannheim']})
# ('Mumbai', {'Mumbai': ['Mumbai'], 'Delhi': ['Mumbai', 'Delhi'], 'Kolkata': ['Mumbai', 'Delhi', 'Kolkata'], 'Bangalore': ['Mumbai', 'Delhi', 'Kolkata', 'Bangalore']})
# ('Delhi', {'Delhi': ['Delhi'], 'Mumbai': ['Delhi', 'Mumbai'], 'Kolkata': ['Delhi', 'Kolkata'], 'Bangalore': ['Delhi', 'Kolkata', 'Bangalore']})
# ('Kolkata', {'Kolkata': ['Kolkata'], 'Delhi': ['Kolkata', 'Delhi'], 'Bangalore': ['Kolkata', 'Bangalore'], 'Mumbai': ['Kolkata', 'Delhi', 'Mumbai']})
# ('Bangalore', {'Bangalore': ['Bangalore'], 'Kolkata': ['Bangalore', 'Kolkata'], 'Delhi': ['Bangalore', 'Kolkata', 'Delhi'], 'Mumbai': ['Bangalore', 'Kolkata', 'Delhi', 'Mumbai']})
# ('TX', {'TX': ['TX'], 'NY': ['TX', 'NY'], 'ALB': ['TX', 'NY', 'ALB']})
# ('NY', {'NY': ['NY'], 'TX': ['NY', 'TX'], 'ALB': ['NY', 'ALB']})
# ('ALB', {'ALB': ['ALB'], 'NY': ['ALB', 'NY'], 'TX': ['ALB', 'NY', 'TX']})

# %% [markdown]
# # 3. Minimum Spanning Tree

# %%
nx.draw_networkx(nx.minimum_spanning_tree(g))

# %% [markdown]
# # 4. Pagerank

# %%
import os
#print(os.listdir('../input/'))

# %%
print(os.getcwd())
# Out:
# /content

# %%
for i in os.walk('/content'):
  print(i)
# Out:
# ('/content', ['.config', 'drive', 'sample_data'], [])
# ('/content/.config', ['logs', 'configurations'], ['gce', '.last_update_check.json', 'config_sentinel', 'active_config', '.last_survey_prompt.yaml', '.last_opt_in_prompt.yaml'])
# ('/content/.config/logs', ['2022.10.07'], [])
# ('/content/.config/logs/2022.10.07', [], ['13.34.26.675197.log', '13.34.49.852351.log', '13.34.50.628315.log', '13.34.17.754134.log', '13.33.55.059309.log', '13.33.29.962578.log'])
# ('/content/.config/configurations', [], ['config_default'])
# ('/content/drive', ['.file-revisions-by-id', 'MyDrive', '.shortcut-targets-by-id', '.Trash-0'], [])
# ('/content/drive/.file-revisions-by-id', [], [])
# ('/content/drive/MyDrive', ['Colab Notebooks', 'GALILEAN-ENS-DISCOVERY', 'IP activités Flora'], ['Document sans titre.gdoc', 'Commande pizzas.gdoc', 'Flora Helmers with Comments.gdoc'])
# ('/content/drive/MyDrive/Colab Notebooks', ['activity 1 fh'], ['activity1.ipynb'])
# ('/content/drive/MyDrive/Colab Notebooks/activity 1 fh', [], [])
# ('/content/drive/MyDrive/IP activités Flora', [], ['facebook.combined.txt', 'wikipedia_to_rdf_graph.ipynb', 'top-graph-algorithms.ipynb'])
# ('/content/drive/.shortcut-targets-by-id', ['1WbP569uLyTz_UT6142I4TtqoLSyEtAx_'], [])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_', ['GALILEAN-ENS-DISCOVERY'], [])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY', ['ToRead', 'DS-Studies', 'Documents', 'Data', 'Queer-Code'], [])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/ToRead', ['Story-Telling', 'Graph-Querying', 'Knowledge-Graph'], [])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/ToRead/Story-Telling', [], ['3526100.pdf'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/ToRead/Graph-Querying', [], ['GPMLSigmod.pdf'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/ToRead/Knowledge-Graph', [], ['Knowledge Graphs: The future of data structures | by Hugo Jiménez | Aug, 2022 | Medium.pdf', 'Constructing knowledge graphs and their biomedical applications .pdf', 'Knowledge-Graphs-Overview.pdf', 'A Practical Approach to Constructing a Knowledge Graph for Cybersecurity.pdf', 'KnowledgeGraphBook.pdf'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/DS-Studies', [], [])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Documents', ['roadmap'], [])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Documents/roadmap', [], ['roadmap.docx'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Data', ['facebook-data'], [])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Data/facebook-data', [], ['facebook.combined.txt'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code', ['.git', 'analysis', 'apps', 'data-gathering', 'data-linking', 'data-modeling', 'data-publishing', 'docs', 'static'], ['README.md', '.gitignore', '.gitattributes', 'remove-na.Rproj', 'renv.lock'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/.git', ['refs', 'objects', 'logs'], ['HEAD', 'config', 'packed-refs', 'index', 'FETCH_HEAD', 'sourcetreeconfig'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/.git/refs', ['heads', 'tags', 'remotes'], [])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/.git/refs/heads', [], ['main'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/.git/refs/tags', [], [])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/.git/refs/remotes', ['origin'], [])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/.git/refs/remotes/origin', [], ['HEAD'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/.git/objects', ['info', 'pack'], [])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/.git/objects/info', [], [])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/.git/objects/pack', [], ['pack-b9597f3f0383e0ca9ecf992aa5718d8318b19acf.pack', 'pack-b9597f3f0383e0ca9ecf992aa5718d8318b19acf.idx'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/.git/logs', ['refs'], ['HEAD'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/.git/logs/refs', ['remotes', 'heads'], [])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/.git/logs/refs/remotes', ['origin'], [])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/.git/logs/refs/remotes/origin', [], ['HEAD'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/.git/logs/refs/heads', [], ['main'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/analysis', ['2022-05-31-status-update', 'img', 'network'], ['authors-viaf-analysis.Rmd', 'plot-full-network.qmd'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/analysis/2022-05-31-status-update', [], ['index.qmd'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/analysis/img', [], ['events_count_en.png', 'events_count_de.png', 'histogram_en.png', 'histogram_de.png'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/analysis/network', [], ['02-look-into-data.R', '01-get-data.R'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/apps', ['companions', 'entity-resolver', 'compare-factgrid-wikidata', 'remove-na-explore-surroundings'], [])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/apps/companions', [], ['app.R', 'global.R', 'queries.R'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/apps/entity-resolver', [], ['index.Rmd', 'get-additional-infos.R'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/apps/compare-factgrid-wikidata', [], ['df_filter_helper.R', 'functions.R', 'index.Rmd', 'queries.R', 'install_packages.R'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/apps/remove-na-explore-surroundings', [], ['choose-relevant-persons.R', 'index.html', 'index.qmd', 'queries.R'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-gathering', ['data', 'analysis', 'entity-resolution', 'from-citavi', 'from-pdf', 'from-website', 'misc', 'from-wikidata', 'named-entity-recognition'], [])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-gathering/data', ['input'], [])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-gathering/data/input', [], ['themengeschichtspfad-no-fullpage-images.pdf'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-gathering/analysis', [], ['find-duplicates-authors-book-posters.R', 'find-duplicates-authors.R', 'open-refine-fingerprint.R', 'misc-refiner.R'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-gathering/entity-resolution', ['chronik', 'entities', 'poster-books'], [])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-gathering/entity-resolution/chronik', [], ['01-within-chronik-ner.R', '03-create-clean-chronik-entities.R', '02-distinct-entities-from-chronik.R'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-gathering/entity-resolution/entities', [], ['01-within-entities.R', '02-other-duplicates.R', '03-within-entities-v2-incl-chronik.R'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-gathering/entity-resolution/poster-books', [], ['01-books-authors-posters-authors.R', '02-distinct-entities-from-books-posters.R', '01-books-publishers-posters-authors.R', '03-create-clean-tables-books-posters.R', '01-books-editors-books-authors.R', '01-books-publishers-books-authors.R'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-gathering/from-citavi', [], ['digital.R', 'poster.R', 'books.R'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-gathering/from-pdf', [], ['themengeschichtspfad.R'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-gathering/from-website', [], ['chronik-after-ner.R', 'chronik-to-wikidata-via-bbw.ipynb', 'scrape-chronik.R', 'chronik-to-wikidata.R'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-gathering/misc', [], ['export-duplicates.R'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-gathering/from-wikidata', ['2022-03-18-stock-taking'], ['cache-db.R'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-gathering/from-wikidata/2022-03-18-stock-taking', [], ['index.Rmd', 'index.html'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-gathering/named-entity-recognition', ['data', 'queer-ner'], ['add-text-to-rubrix.py', 'flair_ner.py', 'huggingface_ner.py', 'train_spacy.ipynb', 'spacy_ner.py', 'spacy_ner_dev.py'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-gathering/named-entity-recognition/data', [], ['base-config.cfg', 'config.cfg'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-gathering/named-entity-recognition/queer-ner', [], ['preprocessing.py'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-linking', ['lobid'], ['check-isbn-in-lobid.R', 'book-authors-viaf.R', 'get-data-from-wikidata.R', 'search-queer-publishers-in-wikidata.R'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-linking/lobid', [], ['01-search-via-isbn.R', '02-search-via-author-title.R', '03-search-via-author.R', '05-fetch-wikidata-qid-from-gnd.R', '04-search-via-publisher.R', 'disambiguate-entities.Rmd', 'analysis.R'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-modeling', ['configs', 'mappings'], ['create-rdf.py', 'query.ipynb'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-modeling/configs', [], ['books-authors.ini', 'books-config.ini', 'posters-config.ini', 'kg_v1.ini'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-modeling/mappings', [], ['books-rules.yml', 'kg_v1.yml', 'books-authors.yml', 'nested_mapping_weird_result.yml', 'posters-rules.yml'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-publishing', ['factgrid', 'wikidata'], [])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-publishing/factgrid', ['entities', 'minor-updates', 'queries'], ['analyse-number-of-items.R', 'add-wikidata-if-wikipedia-articles.R', 'write-wikidata-ids-to-factgrid.R'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-publishing/factgrid/entities', [], ['01-addresses.R', '03-laws.R', '02-parties.R', '05-kz-persons.R', '04-persons.R', '04-persons-bugfixes.R', '07-publishers.R', '06-clubs.R', '10-cities.R', '09-more-locations-from-chronik.R', '08-orgs.R', '13-books.R', '12-events.R', '11-districts-countries.R', '16-entities-publications.R', '15-chronik-events.R', '14-posters.R', '17-awards.R', 'meeting-places.R', 'filter-for-reconciliation.R', 'write-reconciled-data-in-db.R'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-publishing/factgrid/minor-updates', [], ['add-authorship-to-org-authors-as-field-of-engagement.R', 'add-christa-reinig-books.R', 'add-book-class.R', 'add-poster-designers-to-items.R', 'change-target-group-to-importance-for.R'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-publishing/factgrid/queries', [], ['companions_and_relations.rq', 'companions_and_relations_no_constants.rq', 'db_all_person_relations.rq', 'companions_hirschfeld.rq', 'compare-factgrid-wikidata_one_item.rq', 'compare-factgrid-wikidata_many_items.rq', 'get_all_properties_person_with_corresponding_prop.rq', 'get_factgrid_ids_from_wikidata.rq', 'get_gnd_from_fg_and_wd.rq', 'get_all_properties_with_corresponding_prop.rq', 'get_factgrid_ids_from_wikidata-removena.rq', 'network-00-starting-point.rq', 'get_wiki_sitelinks.rq', 'get_wiki_sitelinks_removena.rq', 'lokale-from-factgrid.rq', 'network-02-starting-point.rq', 'network-01-remove-na.rq', 'persons_factgrid_wikidata.rq', 'orgs_factgrid_wikidata.rq', 'network-03-federated.rq', 'time-items.rq', 'test.rq'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-publishing/wikidata', ['data', 'entities', 'misc'], ['add-aliase-from-factgrid.R', 'compare-properties-fg-wd.R', 'get-api-data.R', 'write-factgrid-ids-to-wikidata.R'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-publishing/wikidata/data', [], ['revisions.csv'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-publishing/wikidata/entities', [], ['create-orgs.R', 'create-clubs.R', 'create-bars.R', 'choirs-from-wikipedia.R', 'create-choires.R', 'create-queer-publishers.R', 'create-persons.R', 'place-of-address.R', 'gedenkstätten.R'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/data-publishing/wikidata/misc', [], ['add-lesbengeschichteorg-source.R', 'german-lgbt-magazines.R'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/docs', ['img', 'libs'], ['01-data-gathering.Rmd', '02-data-modeling.Rmd', '99-misc.Rmd', 'data-gathering.html', '404.html', '03-data-linking.Rmd', 'data-linking-1.html', 'data-modeling.html', 'data-modelling.html', 'data-linking.html', 'index.Rmd', 'index.html', 'misc.html', 'search_index.json'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/docs/img', [], ['2022-04-14-10-53-50.png', '2022-04-14-10-56-51.png', 'dm-books.png', 'dm-posters.png', 'who-is-who-ex.png'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/docs/libs', ['anchor-sections-1.1.0', 'gitbook-2.6.7', 'jquery-3.6.0'], [])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/docs/libs/anchor-sections-1.1.0', [], ['anchor-sections-symbol.css', 'anchor-sections-icon.css', 'anchor-sections-hash.css', 'anchor-sections.css', 'anchor-sections.js'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/docs/libs/gitbook-2.6.7', ['css', 'js'], [])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/docs/libs/gitbook-2.6.7/css', ['fontawesome'], ['plugin-clipboard.css', 'plugin-fontsettings.css', 'plugin-bookdown.css', 'plugin-table.css', 'plugin-search.css', 'plugin-highlight.css', 'style.css'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/docs/libs/gitbook-2.6.7/css/fontawesome', [], ['fontawesome-webfont.ttf'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/docs/libs/gitbook-2.6.7/js', [], ['app.min.js', 'lunr.js', 'plugin-clipboard.js', 'clipboard.min.js', 'plugin-bookdown.js', 'jquery.highlight.js', 'plugin-sharing.js', 'plugin-search.js', 'plugin-fontsettings.js'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/docs/libs/jquery-3.6.0', [], ['jquery-3.6.0.js', 'jquery-3.6.0.min.js', 'jquery-3.6.0.min.map'])
# ('/content/drive/.shortcut-targets-by-id/1WbP569uLyTz_UT6142I4TtqoLSyEtAx_/GALILEAN-ENS-DISCOVERY/Queer-Code/static', [], ['wikidata-queer-items.tsv', 'string-mapping.yml', 'wikidata-queer-properties.tsv'])
# ('/content/drive/.Trash-0', ['files', 'info'], [])
# ('/content/drive/.Trash-0/files', [], [])
# ('/content/drive/.Trash-0/info', [], [])
# ('/content/sample_data', [], ['anscombe.json', 'README.md', 'california_housing_test.csv', 'mnist_test.csv', 'mnist_train_small.csv', 'california_housing_train.csv'])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print(os.getcwd())
# Out:
# /content

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.listdir('/content/drive/MyDrive/GALILEAN-ENS-DISCOVERY/Data/facebook-data')
# Out:
# ['facebook.combined.txt']

# %%
pathFb = "/content/drive/MyDrive/GALILEAN-ENS-DISCOVERY/Data/facebook-data"

# %%
# reading the dataset

fb = nx.read_edgelist(pathFb +'/facebook.combined.txt', create_using = nx.Graph(), nodetype = int)

# %%
print(nx.info(fb))
# Out:
# Graph with 3959 nodes and 84243 edges

# %%
pos = nx.spring_layout(fb)

import warnings
warnings.filterwarnings('ignore')

plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (20, 15)
plt.axis('off')
nx.draw_networkx(fb, pos, with_labels = False, node_size = 35)
plt.show()

# %%
pagerank = nx.pagerank(fb)

# %%
import operator
sorted_pagerank = sorted(pagerank.items(), key=operator.itemgetter(1),reverse=True)
print(sorted_pagerank[:5])
# Out:
# [(483, 0.0013599133699007313), (3830, 0.0013447129836372254), (2313, 0.0009589781687839365), (376, 0.0009407023103604414), (2047, 0.0009130312315135463)]

# %%
first_degree_connected_nodes = list(fb.neighbors(3830))
second_degree_connected_nodes = []
for x in first_degree_connected_nodes:
    second_degree_connected_nodes+=list(fb.neighbors(x))
second_degree_connected_nodes.remove(3830)
second_degree_connected_nodes = list(set(second_degree_connected_nodes))

subgraph_3437 = nx.subgraph(fb,first_degree_connected_nodes+second_degree_connected_nodes,)

# %%
pos = nx.spring_layout(subgraph_3437)

# %%
import warnings
warnings.filterwarnings('ignore')
node_color = ['yellow' if v == 3437 else 'red' for v in subgraph_3437]
node_size =  [1000 if v == 3437 else 35 for v in subgraph_3437]
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (20, 15)
plt.axis('off')

nx.draw_networkx(subgraph_3437, pos, with_labels = False, node_color=node_color,node_size=node_size )
plt.show()

# %% [markdown]
# # 5. Centrality

# %%
pos = nx.spring_layout(subgraph_3437)
betweennessCentrality = nx.betweenness_centrality(subgraph_3437,normalized=True, endpoints=True)

# %%
node_size =  [v * 10000 for v in betweennessCentrality.values()]
plt.figure(figsize=(20,20))
nx.draw_networkx(subgraph_3437, pos=pos, with_labels=False,
                 node_size=node_size )
plt.axis('off')
# Out:
# (-1.0866327122949513,
#  1.198277316552914,
#  -0.8760546158947095,
#  1.0284233812625818)
